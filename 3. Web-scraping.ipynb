# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/List_of_books_considered_the_best"
response = requests.get(url).text

# %%
soup = BeautifulSoup(response, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of books considered the best - Wikipedia
#   </title>
#   <script>
# ...

# %%
table = soup.find('table',{ 'class':'wikitable sortable'})
pd.read_html(str(table))[0]
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_7100\179595180.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(str(table))[0]
#                              Name               Author     Year  \
# 0              All The King's Men   Robert Penn Warren     1946
# 1                     Animal Farm        George Orwell     1945
# 2          Appointment in Samarra          John O'Hara     1934
# 3                       Atonement           Ian McEwan     2001
# 4                         Beloved        Toni Morrison     1987
# 5                   The Big Sleep     Raymond Chandler     1939
# 6                        Catch-22        Joseph Heller     1961
# 7          The Catcher In The Rye        J.D. Salinger     1951
# 8    A Dance to the Music of Time       Anthony Powell  1951-75
# 9           The Day of the Locust       Nathanael West     1939
# ...

# %% [markdown]
# # Scraping Cars Data

# %%
url = "https://www.goodcarbadcar.net/2023-us-vehicle-sales-figures-by-model/"
response = requests.get(url).text

# %%
soup = BeautifulSoup(response, "html.parser")

# %%
soup.find('table', {'id' : 'table_1'})
# Out:
# <table class="responsive display nowrap data-t data-t wpDataTable wpDataTableID-6341" data-described-by="table_1_desc" data-wpdatatable_id="6341" id="table_1" style="">
# <!-- Table header -->
# <thead>
# <tr>
# <th class="wdtheader sort" data-class="expand" style="">Model</th> <th class="phone,tablet wdtheader sort numdata integer" data-hide="phone,tablet" style="">Month</th> <th class="phone,tablet wdtheader sort numdata integer" data-hide="phone,tablet" style="">Month LY</th> <th class="phone,tablet wdtheader sort numdata formula" data-hide="phone,tablet" style="">Change</th> <th class="wdtheader sort numdata integer" style="">YTD</th> <th class="wdtheader sort numdata integer" style="">YTD LY</th> <th class="wdtheader sort numdata formula" style="">YTD Change</th> </tr>
# </thead>
# <!-- /Table header -->
# <!-- Table body -->
# <tbody>
# <tr id="table_6341_row_0">
# ...

# %%
table= soup.find_all('tr')

# %%
data_list = [title.text for title in table]

# %%
cleaned_data = [item.strip().split('\n') for item in data_list]

# %%
data_subset = [row[:7] for row in cleaned_data]

# %%
pd.DataFrame(data_subset[1:760],columns=['Model', 'Month', 'Month_LY', 'Change', 'YTD', 'YTD LY', 'YTD Change'])
# Out:
#                Model   Month Month_LY  Change      YTD   YTD LY YTD Change
# 0            Mazda 3   2,205    2,778  -20.63   25,569   22,758      12.35
# 1     Toyota 4Runner  10,344   11,333   -8.73   87,651  104,752     -16.33
# 2    Volvo 60-Series   1,775      648  173.92    9,281    6,169      50.45
# 3    Volvo 90-Series     147      113   30.09    1,782    1,517      17.47
# 4       Honda Accord  15,346   11,751   30.59  167,548  122,214      37.09
# ..               ...     ...      ...     ...      ...      ...        ...
# 754  Volvo 60-Series   1,263      592     965      471      280        433
# 755  Volvo 90-Series     154      147     197      219      184        183
# 756        Volvo C40      76      159     389      522      554        351
# 757       Volvo XC40     861    1,530   1,596    1,312    1,836      1,686
# 758       Volvo XC60   2,668    2,020   3,130    3,710    3,084      2,720
#
# [759 rows x 7 columns]

# %%
df.to_csv('U.S Vehicle Sales')
